# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/urdu-language-speech-dataset/README.md
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F9_A061.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F42_A094.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F41_A093.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F38_A090.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F18_A018.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F11_A033.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F2_A02.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F8_A08.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F4_A056.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F45_A097.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F30_A082.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F16_A038.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F43_A095.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F16_A016.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F46_A098.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F10_A010.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F21_A021.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM3_F1_A051.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F1_A023.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F25_A077.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F1_A053.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F12_A064.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F32_A084.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F21_A043.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F19_A041.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F18_A070.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F3_A03.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F39_A091.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F16_A068.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F23_A075.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F8_A060.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F22_A044.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F21_A073.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F11_A063.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F13_A035.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F34_A086.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F10_A032.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F28_A050.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F4_A026.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F2_A054.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F26_A078.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F25_A047.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F11_A011.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F26_A048.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F27_A079.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F48_A0100.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F7_A059.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F17_A017.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F7_A07.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F17_A069.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F14_A036.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F6_A058.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F18_A040.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F9_A09.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F24_A076.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F5_A057.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F47_A099.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F3_A025.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F35_A087.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F6_A028.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F20_A020.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F20_A072.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F44_A096.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F8_A030.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F33_A085.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F17_A039.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F31_A083.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F1_A01.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F37_A089.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F6_A06.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F5_A05.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F27_A049.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F20_A042.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F24_A046.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F28_A080.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F9_A031.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F23_A045.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F15_A067.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F4_A04.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F14_A014.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F7_A029.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F22_A022.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F40_A092.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F22_A074.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F5_A027.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F14_A066.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F10_A062.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F13_A065.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F15_A015.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F3_A055.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F36_A088.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F29_A081.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F13_A013.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F15_A037.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F12_A034.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM3_F2_A052.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F12_A012.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM1_F19_A019.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM2_F2_A024.wav
# /kaggle/input/urdu-language-speech-dataset/Angry/SM4_F19_A071.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F20_N048.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F13_N041.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM3_F6_N026.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F72_N0100.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM20_F1_N05.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F39_N067.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F51_N079.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F59_N087.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM22_F1_N019.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SF9_F4_N04.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F37_N065.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM20_F2_N06.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F71_N099.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F66_N094.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F11_N039.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F23_N051.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F8_N036.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F32_N060.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F6_N034.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F44_N072.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM3_F7_N027.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F12_N040.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F1_N029.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F41_N069.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F46_N074.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM21_F3_N017.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F3_N031.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F52_N080.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F65_N093.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F16_N044.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F24_N052.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM21_F2_N016.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F62_N090.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F25_N053.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM20_F3_N07.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F40_N068.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SF9_F1_N01.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SF9_F2_N02.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F14_N042.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F69_N097.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F48_N076.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SF9_F3_N03.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F70_N098.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F4_N032.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F54_N082.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F58_N086.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F67_N095.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F17_N045.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F36_N064.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F42_N070.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F31_N059.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM22_F2_N020.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F27_N055.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F63_N091.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F60_N088.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F53_N081.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F56_N084.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F49_N077.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM3_F5_N025.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F29_N057.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM3_F8_N028.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F5_N033.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F33_N061.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM20_F10_N014.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F35_N063.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F19_N047.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM20_F4_N08.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F55_N083.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F61_N089.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F30_N058.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F50_N078.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM20_F8_N012.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F9_N037.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F21_N049.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F64_N092.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F18_N046.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F7_N035.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F2_N030.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F43_N071.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F22_N050.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F26_N054.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM3_F1_N021.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM3_F3_N023.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM3_F2_N022.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM21_F1_N015.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F15_N043.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F57_N085.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F38_N066.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM20_F7_N011.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM20_F6_N010.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM20_F9_N013.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM3_F4_N024.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F34_N062.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F68_N096.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F28_N056.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM20_F5_N09.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F45_N073.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F10_N038.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM21_F4_N018.wav
# /kaggle/input/urdu-language-speech-dataset/Neutral/SM5_F47_N075.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F4_S054.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM6_F4_S0100.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F31_S043.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM27_F1_S093.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F23_S073.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F2_S014.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F35_S085.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F29_S041.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F10_S060.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SF11_F4_S06.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F28_S078.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F12_S024.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F5_S055.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F9_S059.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM6_F1_S097.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F20_S070.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F38_S088.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F37_S049.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F34_S046.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F24_S074.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F20_S032.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F6_S018.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F22_S034.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F28_S040.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM27_F4_S096.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F31_S081.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F24_S036.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F33_S045.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM23_F2_S08.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F30_S080.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F37_S087.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F18_S068.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F32_S044.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SF10_F2_S02.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F23_S035.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SF10_F1_S01.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F27_S039.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM6_F3_S099.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F13_S063.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SF11_F1_S03.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F7_S019.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F2_S052.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F19_S031.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F5_S017.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F36_S048.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F32_S082.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F16_S028.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F39_S089.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM27_F2_S094.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F29_S079.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM23_F1_S07.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F9_S021.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F12_S062.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F27_S077.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F30_S042.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM26_F1_S091.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F16_S066.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM23_F3_S09.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F26_S038.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F34_S084.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F18_S030.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F14_S026.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F36_S086.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F17_S029.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F3_S053.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F6_S056.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F11_S061.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F21_S033.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SF11_F2_S04.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F25_S037.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F10_S022.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SF11_F3_S05.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F17_S067.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F4_S016.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM27_F3_S095.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM6_F2_S098.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F3_S015.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F35_S047.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F19_S069.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM26_F2_S092.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F8_S058.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F8_S020.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F21_S071.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM23_F4_S010.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F15_S065.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F25_S075.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM23_F6_S012.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F33_S083.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM23_F5_S011.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F22_S072.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F1_S051.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F7_S057.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F26_S076.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F15_S027.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F14_S064.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F13_S025.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F1_S013.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM25_F40_S090.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F38_S050.wav
# /kaggle/input/urdu-language-speech-dataset/Sad/SM24_F11_S023.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM5_F1_H055.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F9_H09.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F7_H07.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F18_H090.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM17_F2_H048.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM5_F3_H057.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F27_H099.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM5_F2_H056.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F9_H081.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F26_H098.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F8_H08.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM18_F1_H049.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F12_H012.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F2_H02.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM5_F8_H062.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM6_F5_H067.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F13_H085.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF4_F3_H019.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F14_H086.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF3_F1_H015.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F1_H025.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM6_F2_H064.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF4_F2_H018.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F3_H027.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F6_H078.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F24_H096.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM19_F2_H052.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF7_F6_H044.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F11_H083.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F28_H0100.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF7_F4_H042.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F8_H032.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F23_H095.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F11_H011.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F4_H04.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F6_H030.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F5_H029.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F25_H097.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F1_H01.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF8_F1_H045.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM19_F1_H051.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM17_F1_H047.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F9_H033.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F12_H084.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM6_F8_H070.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F11_H035.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM6_F1_H063.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F5_H077.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F5_H05.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF7_F2_H040.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF5_F3_H023.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF5_F2_H022.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F10_H010.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM3_F2_H054.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F16_H088.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F20_H092.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F1_H073.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF3_F2_H016.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F13_H037.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF7_F5_H043.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F14_H038.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF8_F2_H046.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF4_F1_H017.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF5_F4_H024.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F17_H089.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM5_F4_H058.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF5_F1_H021.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF4_F4_H020.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F4_H028.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F2_H074.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F8_H080.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM5_F7_H061.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F6_H06.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F7_H031.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF2_F1_H013.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF2_F2_H014.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F2_H026.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF1_F3_H03.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM18_F2_H050.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM5_F5_H059.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM6_F7_H069.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF7_F3_H041.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F22_H094.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F4_H076.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM6_F4_H066.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM6_F3_H065.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F10_H034.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM5_F6_H060.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM6_F10_H072.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM3_F1_H053.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F3_H075.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF6_F12_H036.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SF7_F1_H039.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F21_H093.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F19_H091.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM6_F9_H071.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F7_H079.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM6_F6_H068.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F15_H087.wav
# /kaggle/input/urdu-language-speech-dataset/Happy/SM7_F10_H082.wav

# %% [markdown]
# ##  Importing Libraries

# %%
import os
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import librosa
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
# Out:
# 2024-08-21 18:39:01.527712: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-21 18:39:01.527864: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-21 18:39:01.720190: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Defining Parameters and Paths

# %%
# Path to the directory containing audio files
audio_dir = '/kaggle/input/urdu-language-speech-dataset'
classes = ['Angry', 'Happy', 'Neutral', 'Sad']

# %% [markdown]
# ## Function to Load Dataset

# %%
# Function to get audio file paths and labels
def load_dataset(base_dir, classes):
    audio_paths = []
    labels = []
    for label in classes:
        class_dir = os.path.join(base_dir, label)
        for file_name in os.listdir(class_dir):
            if file_name.endswith('.wav'):  # Ensure it's an audio file
                audio_paths.append(os.path.join(class_dir, file_name))
                labels.append(label)
    return audio_paths, labels

# %% [markdown]
# ## Loading and Preprocessing Audio Data

# %%
# Load audio file paths and labels
audio_paths, labels = load_dataset(audio_dir, classes)

# Parameters for audio preprocessing
sampling_rate = 16000  # VGGish often uses 16 kHz

def preprocess_audio(audio_path):
    y, sr = librosa.load(audio_path, sr=sampling_rate)
    # VGGish requires files of 96 ms
    y = librosa.util.fix_length(y, size=96000)  # 1.6 seconds of audio at 16 kHz
    return y

# Preprocess audio data
audio_data = [preprocess_audio(path) for path in audio_paths]

# %% [markdown]
# ## Extracting VGGish Features

# %%
# Load pre-trained VGGish model from TensorFlow Hub
vggish_model = hub.load("https://tfhub.dev/google/vggish/1")

# Extract VGGish features
def extract_vggish_features(audio):
    audio = tf.convert_to_tensor(audio, dtype=tf.float32)
    features = vggish_model(audio)
    return features.numpy()

# Extract features for each audio file
vggish_features = [extract_vggish_features(data) for data in audio_data]

# %% [markdown]
# ## Extracting MFCC Features

# %%
# Extract MFCC features
def extract_mfcc_features(audio):
    mfccs = librosa.feature.mfcc(y=audio, sr=sampling_rate, n_mfcc=13)
    return mfccs.T  # Transpose to have shape (n_frames, n_mfcc)

# Extract MFCC features for each audio file
mfcc_features = [extract_mfcc_features(data) for data in audio_data]

# %% [markdown]
#  ## Preparing Features for Training

# %%
# Convert to numpy arrays
vggish_features = np.array(vggish_features)
mfcc_features = np.array(mfcc_features)

# Flatten features
vggish_features_flat = vggish_features.reshape(len(vggish_features), -1)
mfcc_features_flat = mfcc_features.reshape(len(mfcc_features), -1)

# Concatenate VGGish and MFCC features
features_combined = np.hstack((vggish_features_flat, mfcc_features_flat))

# Normalize features
scaler = StandardScaler()
features_normalized = scaler.fit_transform(features_combined)

# %% [markdown]
# ## Encoding Labels and Splitting Data

# %%
# Encode labels
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# Split data into training and test sets
X_train, X_test, y_train, y_test, audio_train, audio_test = train_test_split(
    features_normalized, labels_encoded, audio_paths, test_size=0.2, random_state=42
)

# %% [markdown]
# ## Creating and Training the SVM Model

# %%
# Create and train the SVM model
svm_model = SVC(kernel='rbf', C=1)
svm_model.fit(X_train, y_train)
# Out:
# SVC(C=1)

# %% [markdown]
# ## Evaluating the Model

# %%
# Predict on the test set
y_pred = svm_model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9375
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        26
#            1       0.94      0.83      0.88        18
#            2       0.86      1.00      0.92        18
#            3       1.00      0.89      0.94        18
#
#     accuracy                           0.94        80
#    macro avg       0.94      0.93      0.93        80
# weighted avg       0.94      0.94      0.94        80
